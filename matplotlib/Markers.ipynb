# %%
import matplotlib.pyplot as plt
import numpy as np

x=[1,3,5,6]
y=[1,2,3,4]
plt.plot(x,y,marker='o')

# %%
import matplotlib.pyplot as plt
import numpy as np

x=[1,3,5,6]
y=[1,2,3,4]
plt.plot(x,y,linewidth=10.5)
