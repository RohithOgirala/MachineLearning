# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[1,12,13,14]
plt.title('Line plot')
plt.xlabel('x axis')
plt.ylabel('y axis')

plt.plot(x,y)
plt.grid()
plt.show()

# %%
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
