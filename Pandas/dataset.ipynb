# %%
import numpy as numpy
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\rohit\OneDrive\Desktop\Machine learning\Social_Network_Ads (1).csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.tail()
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
df['Age'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      19
# 1      35
# 2      26
# 3      27
# 4      19
#        ..
# 395    46
# 396    51
# 397    50
# 398    36
# 399    49
# Name: Age, Length: 400, dtype: int64>

# %%
df.size
# Out:
# 2000

# %%
df.shape
# Out:
# (400, 5)

# %% [markdown]
# CHECKING NULLVALUES

# %%
df.isna().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %% [markdown]
# SCLICING THE DATA

# %% [markdown]
# SCLICING ROW WISE

# %%
df[0:11:5]
# Out:
#      User ID  Gender  Age  EstimatedSalary  Purchased
# 0   15624510    Male   19            19000          0
# 5   15728773    Male   27            58000          0
# 10  15570769  Female   26            80000          0

# %% [markdown]
# SCLICING ROW AND COLOUM WISE

# %%
df.iloc[0:3,0:2]
# Out:
#     User ID  Gender
# 0  15624510    Male
# 1  15810944    Male
# 2  15668575  Female

# %% [markdown]
# SELECT RANDOM COLOUMS BY THER POSITION

# %%
df.iloc[:,[1,2,3]]
# Out:
#      Gender  Age  EstimatedSalary
# 0      Male   19            19000
# 1      Male   35            20000
# 2    Female   26            43000
# 3    Female   27            57000
# 4      Male   19            76000
# ..      ...  ...              ...
# 395  Female   46            41000
# 396    Male   51            23000
# 397  Female   50            20000
# 398    Male   36            33000
# 399  Female   49            36000
#
# [400 rows x 3 columns]

# %%
df.loc[19:26,['User ID','Age','EstimatedSalary']]
# Out:
#      User ID  Age  EstimatedSalary
# 19  15621083   48            29000
# 20  15649487   45            22000
# 21  15736760   47            49000
# 22  15714658   48            41000
# 23  15599081   45            22000
# 24  15705113   46            23000
# 25  15631159   47            20000
# 26  15792818   49            28000

# %% [markdown]
#  SETTING THE INDEX

# %%
df.set_index('User ID',inplace=True)
df
# Out:
#           Gender  Age  EstimatedSalary  Purchased
# User ID
# 15624510    Male   19            19000          0
# 15810944    Male   35            20000          0
# 15668575  Female   26            43000          0
# 15603246  Female   27            57000          0
# 15804002    Male   19            76000          0
# ...          ...  ...              ...        ...
# 15691863  Female   46            41000          1
# 15706071    Male   51            23000          1
# 15654296  Female   50            20000          1
# 15755018    Male   36            33000          0
# 15594041  Female   49            36000          1
#
# [400 rows x 4 columns]

# %%
df.reset_index('User ID',inplace=True)
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %% [markdown]
# CHANGING TO NEW CSV

# %%
df_18=df[df['Age']>18]
df_18
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [395 rows x 5 columns]

# %%
df_18.to_csv("New_CSV")

# %%
df[df['Age']==18]
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 14   15628972    Male   18            82000          0
# 51   15764195  Female   18            44000          0
# 76   15746737    Male   18            52000          0
# 141  15666141  Female   18            68000          0
# 165  15578738  Female   18            86000          0

# %%
df[df['Gender']=='Male']
# Out:
#       User ID Gender  Age  EstimatedSalary  Purchased
# 0    15624510   Male   19            19000          0
# 1    15810944   Male   35            20000          0
# 4    15804002   Male   19            76000          0
# 5    15728773   Male   27            58000          0
# 8    15600575   Male   25            33000          0
# ..        ...    ...  ...              ...        ...
# 390  15807837   Male   48            33000          1
# 391  15592570   Male   47            23000          1
# 393  15635893   Male   60            42000          1
# 396  15706071   Male   51            23000          1
# 398  15755018   Male   36            33000          0
#
# [196 rows x 5 columns]

# %%
df[df['EstimatedSalary']==df['EstimatedSalary'].max()]
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 7    15694829  Female   32           150000          1
# 211  15735878    Male   52           150000          1

# %%
df[(df['Gender']=='Male')&(df['Age']>18)&(df['EstimatedSalary']>33000)&(df['Purchased']==1)]
# Out:
#       User ID Gender  Age  EstimatedSalary  Purchased
# 22   15714658   Male   48            41000          1
# 48   15727696   Male   30           135000          1
# 63   15583681   Male   32           120000          1
# 75   15651983   Male   34           112000          1
# 97   15582492   Male   28           123000          1
# 137  15687491   Male   30           107000          1
# 160  15744279   Male   32           100000          1
# 168  15789815   Male   29           148000          1
# 211  15735878   Male   52           150000          1
# 219  15732987   Male   59           143000          1
# 221  15663161   Male   35            91000          1
# 222  15694879   Male   37           144000          1
# 223  15593715   Male   60           102000          1
# 227  15685346   Male   56           133000          1
# 232  15813113   Male   40           107000          1
# 233  15614187   Male   49            86000          1
# ...
